# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import csv
# %matplotlib inline

# %%
files = os.listdir("./")

for file_ in files:
    print(file_)
#     if ".jpg" in file_:
#         img = plt.imread(file_)
#         plt.imshow(img)
# Out:
# .ipynb_checkpoints
# test60.jpg
# datareader.py
# Test.ipynb
# test_loader.py
# test61.jpg
# test4.csv
# test42.jpg
# test_images.ipynb
# test41.jpg
# test40.jpg
# test6.csv
# __pycache__

# %%
img = plt.imread("test02.jpg")
plt.imshow(img)

# %%
img = plt.imread("test01.jpg")
plt.imshow(img)

# %%
img = plt.imread("test00.jpg")
plt.imshow(img)

# %%
img = plt.imread("test61.jpg")
plt.imshow(img)

# %%
img = plt.imread("test60.jpg")
plt.imshow(img)
